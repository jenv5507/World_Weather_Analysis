# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)
coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,       
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | zaraza
# Processing Record 3 of Set 1 | benguela
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | dryden
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bogorodskoye
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | masuguru
# Processing Record 15 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 1 | cordoba
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | plavinas
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | tuatapere
# Processing Record 29 of Set 1 | olinda
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | polovinnoye
# Processing Record 36 of Set 1 | manaus
# Processing Record 37 of Set 1 | sola
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | los llanos de aridane
# Processing Record 41 of Set 1 | malaya vishera
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | sovetskiy
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | sioux lookout
# Processing Record 47 of Set 1 | fort walton beach
# Processing Record 48 of Set 1 | half moon bay
# Processing Record 49 of Set 1 | lagoa
# Processing Record 50 of Set 1 | cap malheureux
# Processing Record 1 of Set 2 | bolbec
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | puerto escondido
# Processing Record 4 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | mosquera
# Processing Record 7 of Set 2 | isangel
# Processing Record 8 of Set 2 | marsa matruh
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | mildura
# Processing Record 12 of Set 2 | silopi
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | touros
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | fairbanks
# Processing Record 18 of Set 2 | asfi
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | sao jose da coroa grande
# Processing Record 21 of Set 2 | faya
# Processing Record 22 of Set 2 | bontang
# Processing Record 23 of Set 2 | vianden
# Processing Record 24 of Set 2 | kahului
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | rosignano marittimo
# Processing Record 27 of Set 2 | naze
# Processing Record 28 of Set 2 | beringovskiy
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | weston
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | bengkulu
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | nokaneng
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | laagri
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | nangomba
# Processing Record 40 of Set 2 | umarkot
# Processing Record 41 of Set 2 | khorixas
# Processing Record 42 of Set 2 | tezu
# Processing Record 43 of Set 2 | banda aceh
# Processing Record 44 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set 2 | guerrero negro
# Processing Record 49 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 2 | chimbote
# Processing Record 1 of Set 3 | leh
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 3 | nantucket
# Processing Record 5 of Set 3 | portales
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | altayskoye
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | mantua
# Processing Record 11 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 3 | manyana
# Processing Record 13 of Set 3 | salamiyah
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | matara
# Processing Record 16 of Set 3 | quatre cocos
# Processing Record 17 of Set 3 | santiago del estero
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | kurilsk
# Processing Record 21 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | porto belo
# Processing Record 24 of Set 3 | bam
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | merauke
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | andenes
# Processing Record 29 of Set 3 | jacmel
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | mezen
# Processing Record 32 of Set 3 | gerash
# Processing Record 33 of Set 3 | port hardy
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | siderno
# Processing Record 37 of Set 3 | mecca
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | srednekolymsk
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | we
# City not found. Skipping...
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | khandyga
# Processing Record 47 of Set 3 | butajira
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | koslan
# Processing Record 50 of Set 3 | straumen
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 4 | myrtle beach
# Processing Record 5 of Set 4 | margate
# Processing Record 6 of Set 4 | ponta do sol
# Processing Record 7 of Set 4 | seydi
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | krasnoselkup
# Processing Record 10 of Set 4 | ambilobe
# Processing Record 11 of Set 4 | adrar
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | chimoio
# Processing Record 14 of Set 4 | george town
# Processing Record 15 of Set 4 | verkhnyaya inta
# Processing Record 16 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | barra do garcas
# Processing Record 20 of Set 4 | abu zabad
# Processing Record 21 of Set 4 | santa cruz de la palma
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | barrow
# Processing Record 24 of Set 4 | gornopravdinsk
# Processing Record 25 of Set 4 | roald
# Processing Record 26 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | paz de ariporo
# City not found. Skipping...
# Processing Record 30 of Set 4 | odienne
# Processing Record 31 of Set 4 | jamestown
# Processing Record 32 of Set 4 | biak
# Processing Record 33 of Set 4 | baillif
# Processing Record 34 of Set 4 | starosubkhangulovo
# Processing Record 35 of Set 4 | ishigaki
# Processing Record 36 of Set 4 | akyab
# Processing Record 37 of Set 4 | putnok
# Processing Record 38 of Set 4 | dali
# Processing Record 39 of Set 4 | mapimi
# Processing Record 40 of Set 4 | frontera
# Processing Record 41 of Set 4 | el alto
# Processing Record 42 of Set 4 | dunmore town
# Processing Record 43 of Set 4 | tarko-sale
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | san cristobal
# Processing Record 47 of Set 4 | villa bruzual
# Processing Record 48 of Set 4 | micheweni
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 50 of Set 4 | hasaki
# Processing Record 1 of Set 5 | baykit
# Processing Record 2 of Set 5 | planadas
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | mahanoro
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | catamarca
# Processing Record 7 of Set 5 | perth
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | capreol
# Processing Record 10 of Set 5 | bolonchen
# City not found. Skipping...
# Processing Record 11 of Set 5 | montevideo
# Processing Record 12 of Set 5 | lata
# Processing Record 13 of Set 5 | la ronge
# Processing Record 14 of Set 5 | bumba
# Processing Record 15 of Set 5 | shimabara
# Processing Record 16 of Set 5 | dakar
# Processing Record 17 of Set 5 | nishihara
# Processing Record 18 of Set 5 | tongliao
# Processing Record 19 of Set 5 | okhotsk
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | svetlogorsk
# Processing Record 22 of Set 5 | coihaique
# Processing Record 23 of Set 5 | kindu
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | polur
# Processing Record 27 of Set 5 | merrill
# Processing Record 28 of Set 5 | colares
# Processing Record 29 of Set 5 | pemagatsel
# Processing Record 30 of Set 5 | farafangana
# Processing Record 31 of Set 5 | snezhnogorsk
# Processing Record 32 of Set 5 | icatu
# Processing Record 33 of Set 5 | umm lajj
# Processing Record 34 of Set 5 | synya
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | castlebar
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | nosivka
# Processing Record 39 of Set 5 | am timan
# Processing Record 40 of Set 5 | sijunjung
# Processing Record 41 of Set 5 | leningradskiy
# Processing Record 42 of Set 5 | cacule
# Processing Record 43 of Set 5 | yeniseysk
# Processing Record 44 of Set 5 | sanming
# Processing Record 45 of Set 5 | kissidougou
# Processing Record 46 of Set 5 | pingliang
# Processing Record 47 of Set 5 | ponca city
# Processing Record 48 of Set 5 | lasa
# Processing Record 49 of Set 5 | taoudenni
# Processing Record 50 of Set 5 | bismarck
# Processing Record 1 of Set 6 | praia da vitoria
# Processing Record 2 of Set 6 | yeppoon
# Processing Record 3 of Set 6 | morrinhos
# Processing Record 4 of Set 6 | saskylakh
# Processing Record 5 of Set 6 | gushi
# Processing Record 6 of Set 6 | tocopilla
# Processing Record 7 of Set 6 | natchitoches
# Processing Record 8 of Set 6 | santa quiteria do maranhao
# Processing Record 9 of Set 6 | najran
# Processing Record 10 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 6 | makinsk
# Processing Record 12 of Set 6 | coffs harbour
# Processing Record 13 of Set 6 | taksimo
# Processing Record 14 of Set 6 | kaeo
# Processing Record 15 of Set 6 | beloha
# Processing Record 16 of Set 6 | mucurapo
# Processing Record 17 of Set 6 | sahy
# Processing Record 18 of Set 6 | parabel
# Processing Record 19 of Set 6 | san patricio
# Processing Record 20 of Set 6 | nimes
# Processing Record 21 of Set 6 | mopti
# Processing Record 22 of Set 6 | la algaba
# Processing Record 23 of Set 6 | aklavik
# Processing Record 24 of Set 6 | flin flon
# Processing Record 25 of Set 6 | guangyuan
# Processing Record 26 of Set 6 | paramonga
# Processing Record 27 of Set 6 | ribeira grande
# Processing Record 28 of Set 6 | jawar
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | yaguajay
# Processing Record 31 of Set 6 | galesong
# Processing Record 32 of Set 6 | nalbari
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | ust-ilimsk
# Processing Record 35 of Set 6 | constitucion
# Processing Record 36 of Set 6 | bairiki
# Processing Record 37 of Set 6 | pokrovsk
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | kupang
# Processing Record 40 of Set 6 | khromtau
# Processing Record 41 of Set 6 | rabo de peixe
# Processing Record 42 of Set 6 | mamallapuram
# Processing Record 43 of Set 6 | roseto degli abruzzi
# Processing Record 44 of Set 6 | ostersund
# Processing Record 45 of Set 6 | riyadh
# Processing Record 46 of Set 6 | coronado
# Processing Record 47 of Set 6 | baijiantan
# Processing Record 48 of Set 6 | nanortalik
# Processing Record 49 of Set 6 | abalak
# Processing Record 50 of Set 6 | buchanan
# Processing Record 1 of Set 7 | vardo
# Processing Record 2 of Set 7 | dangriga
# Processing Record 3 of Set 7 | road town
# Processing Record 4 of Set 7 | mehamn
# Processing Record 5 of Set 7 | port blair
# Processing Record 6 of Set 7 | nabire
# Processing Record 7 of Set 7 | ugoofaaru
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | waipawa
# Processing Record 10 of Set 7 | port macquarie
# Processing Record 11 of Set 7 | la argentina
# Processing Record 12 of Set 7 | inuvik
# Processing Record 13 of Set 7 | simbahan
# Processing Record 14 of Set 7 | lazaro cardenas
# Processing Record 15 of Set 7 | seguela
# Processing Record 16 of Set 7 | cedar city
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | veere
# Processing Record 19 of Set 7 | mana
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | bondoukou
# Processing Record 22 of Set 7 | pemangkat
# Processing Record 23 of Set 7 | kushmurun
# Processing Record 24 of Set 7 | babag
# Processing Record 25 of Set 7 | fortuna
# Processing Record 26 of Set 7 | husavik
# Processing Record 27 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 7 | makakilo city
# Processing Record 29 of Set 7 | mandalgovi
# Processing Record 30 of Set 7 | sibolga
# Processing Record 31 of Set 7 | bar harbor
# Processing Record 32 of Set 7 | petatlan
# Processing Record 33 of Set 7 | vrede
# Processing Record 34 of Set 7 | khorramshahr
# Processing Record 35 of Set 7 | ruwi
# Processing Record 36 of Set 7 | xining
# Processing Record 37 of Set 7 | yumen
# Processing Record 38 of Set 7 | tilichiki
# Processing Record 39 of Set 7 | neiafu
# Processing Record 40 of Set 7 | russell
# Processing Record 41 of Set 7 | durazno
# Processing Record 42 of Set 7 | voh
# Processing Record 43 of Set 7 | tiszapuspoki
# Processing Record 44 of Set 7 | richards bay
# Processing Record 45 of Set 7 | la plata
# Processing Record 46 of Set 7 | moose factory
# Processing Record 47 of Set 7 | kamenka
# Processing Record 48 of Set 7 | frederikshavn
# Processing Record 49 of Set 7 | fukue
# Processing Record 50 of Set 7 | ipira
# Processing Record 1 of Set 8 | henties bay
# Processing Record 2 of Set 8 | muroto
# Processing Record 3 of Set 8 | mattru
# Processing Record 4 of Set 8 | katherine
# Processing Record 5 of Set 8 | evensk
# Processing Record 6 of Set 8 | dunyapur
# Processing Record 7 of Set 8 | byron bay
# Processing Record 8 of Set 8 | erenhot
# Processing Record 9 of Set 8 | stettler
# Processing Record 10 of Set 8 | bahir dar
# Processing Record 11 of Set 8 | noumea
# Processing Record 12 of Set 8 | kapit
# Processing Record 13 of Set 8 | kandrian
# Processing Record 14 of Set 8 | prince rupert
# Processing Record 15 of Set 8 | yuzhno-kurilsk
# Processing Record 16 of Set 8 | dingle
# Processing Record 17 of Set 8 | baherden
# Processing Record 18 of Set 8 | great yarmouth
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | sciacca
# Processing Record 21 of Set 8 | nuevo laredo
# Processing Record 22 of Set 8 | vila franca do campo
# Processing Record 23 of Set 8 | fairmont
# Processing Record 24 of Set 8 | solnechnyy
# Processing Record 25 of Set 8 | gat
# Processing Record 26 of Set 8 | arnedo
# Processing Record 27 of Set 8 | kungurtug
# Processing Record 28 of Set 8 | rio gallegos
# Processing Record 29 of Set 8 | jiangyou
# Processing Record 30 of Set 8 | biskamzha
# Processing Record 31 of Set 8 | waddan
# Processing Record 32 of Set 8 | dalby
# Processing Record 33 of Set 8 | ossora
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | luoyang
# Processing Record 36 of Set 8 | guangshui
# Processing Record 37 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 8 | ayna
# Processing Record 39 of Set 8 | porto novo
# Processing Record 40 of Set 8 | necochea
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 8 | alofi
# Processing Record 44 of Set 8 | olutanga
# Processing Record 45 of Set 8 | kokopo
# Processing Record 46 of Set 8 | khandbari
# Processing Record 47 of Set 8 | avenal
# Processing Record 48 of Set 8 | poum
# Processing Record 49 of Set 8 | conde
# Processing Record 50 of Set 8 | zyryanovsk
# Processing Record 1 of Set 9 | shima
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 9 | asosa
# Processing Record 5 of Set 9 | kaitangata
# Processing Record 6 of Set 9 | tessalit
# Processing Record 7 of Set 9 | san quintin
# Processing Record 8 of Set 9 | almaznyy
# Processing Record 9 of Set 9 | xai-xai
# Processing Record 10 of Set 9 | forbes
# Processing Record 11 of Set 9 | juliaca
# Processing Record 12 of Set 9 | aguas formosas
# Processing Record 13 of Set 9 | santa rosa
# Processing Record 14 of Set 9 | talnakh
# Processing Record 15 of Set 9 | constantine
# Processing Record 16 of Set 9 | anadyr
# Processing Record 17 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 9 | matamoros
# Processing Record 19 of Set 9 | dalianwan
# Processing Record 20 of Set 9 | namibe
# Processing Record 21 of Set 9 | westport
# Processing Record 22 of Set 9 | arkadelphia
# Processing Record 23 of Set 9 | pingshan
# Processing Record 24 of Set 9 | haimen
# Processing Record 25 of Set 9 | mustasaari
# Processing Record 26 of Set 9 | indianola
# Processing Record 27 of Set 9 | aksarka
# Processing Record 28 of Set 9 | mount isa
# Processing Record 29 of Set 9 | anajatuba
# Processing Record 30 of Set 9 | la palma
# Processing Record 31 of Set 9 | namatanai
# Processing Record 32 of Set 9 | san fernando
# Processing Record 33 of Set 9 | dennery
# Processing Record 34 of Set 9 | salamanca
# Processing Record 35 of Set 9 | kokoda
# Processing Record 36 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | pontes e lacerda
# Processing Record 39 of Set 9 | cockburn town
# Processing Record 40 of Set 9 | ipswich
# Processing Record 41 of Set 9 | bud
# Processing Record 42 of Set 9 | da nang
# Processing Record 43 of Set 9 | high prairie
# Processing Record 44 of Set 9 | chardara
# Processing Record 45 of Set 9 | oyama
# Processing Record 46 of Set 9 | umm bab
# Processing Record 47 of Set 9 | havoysund
# Processing Record 48 of Set 9 | payson
# Processing Record 49 of Set 9 | oum hadjer
# Processing Record 50 of Set 9 | san juan
# Processing Record 1 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 10 | bamiantong
# Processing Record 3 of Set 10 | soligalich
# Processing Record 4 of Set 10 | mangit
# Processing Record 5 of Set 10 | klaksvik
# Processing Record 6 of Set 10 | privas
# Processing Record 7 of Set 10 | hambantota
# Processing Record 8 of Set 10 | bubaque
# Processing Record 9 of Set 10 | nanchang
# Processing Record 10 of Set 10 | bardiyah
# Processing Record 11 of Set 10 | ario
# City not found. Skipping...
# Processing Record 12 of Set 10 | clyde river
# Processing Record 13 of Set 10 | meadow lake
# Processing Record 14 of Set 10 | deputatskiy
# Processing Record 15 of Set 10 | catalao
# Processing Record 16 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 10 | angoche
# Processing Record 18 of Set 10 | rio grande
# Processing Record 19 of Set 10 | sterling
# Processing Record 20 of Set 10 | verkhnevilyuysk
# Processing Record 21 of Set 10 | kadiri
# Processing Record 22 of Set 10 | makubetsu
# Processing Record 23 of Set 10 | bijie
# Processing Record 24 of Set 10 | dajal
# Processing Record 25 of Set 10 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 26 of Set 10 | aden
# Processing Record 27 of Set 10 | kondinskoye
# Processing Record 28 of Set 10 | aasiaat
# Processing Record 29 of Set 10 | cavalcante
# Processing Record 30 of Set 10 | tomatlan
# Processing Record 31 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 10 | kiama
# Processing Record 33 of Set 10 | port moresby
# Processing Record 34 of Set 10 | waingapu
# Processing Record 35 of Set 10 | zhanaozen
# Processing Record 36 of Set 10 | urumqi
# Processing Record 37 of Set 10 | khvoynaya
# Processing Record 38 of Set 10 | rocha
# Processing Record 39 of Set 10 | brazzaville
# Processing Record 40 of Set 10 | muros
# Processing Record 41 of Set 10 | saint-raymond
# Processing Record 42 of Set 10 | talcahuano
# Processing Record 43 of Set 10 | pjanici
# Processing Record 44 of Set 10 | port lincoln
# Processing Record 45 of Set 10 | okahandja
# Processing Record 46 of Set 10 | ust-nera
# Processing Record 47 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 10 | cape coast
# Processing Record 49 of Set 10 | ilulissat
# Processing Record 50 of Set 10 | lorengau
# Processing Record 1 of Set 11 | novo selo
# Processing Record 2 of Set 11 | grindavik
# Processing Record 3 of Set 11 | shchelkun
# Processing Record 4 of Set 11 | bertoua
# Processing Record 5 of Set 11 | longyan
# Processing Record 6 of Set 11 | haapiti
# Processing Record 7 of Set 11 | inhambane
# Processing Record 8 of Set 11 | le vauclin
# Processing Record 9 of Set 11 | port hedland
# Processing Record 10 of Set 11 | comodoro rivadavia
# Processing Record 11 of Set 11 | vanimo
# Processing Record 12 of Set 11 | saint-lo
# Processing Record 13 of Set 11 | shingu
# Processing Record 14 of Set 11 | beypur
# City not found. Skipping...
# Processing Record 15 of Set 11 | madras
# Processing Record 16 of Set 11 | halden
# Processing Record 17 of Set 11 | griffith
# Processing Record 18 of Set 11 | talara
# Processing Record 19 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 11 | belfast
# Processing Record 21 of Set 11 | mongo
# Processing Record 22 of Set 11 | hearst
# Processing Record 23 of Set 11 | bargi
# Processing Record 24 of Set 11 | ottawa
# Processing Record 25 of Set 11 | high level
# Processing Record 26 of Set 11 | graneros
# Processing Record 27 of Set 11 | mackay
# Processing Record 28 of Set 11 | anloga
# Processing Record 29 of Set 11 | lubao
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | sao gabriel da cachoeira
# Processing Record 32 of Set 11 | vanavara
# Processing Record 33 of Set 11 | oistins
# Processing Record 34 of Set 11 | hofn
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | datong
# Processing Record 37 of Set 11 | kanelovskaya
# Processing Record 38 of Set 11 | tingi
# Processing Record 39 of Set 11 | japura
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | tuy hoa
# Processing Record 42 of Set 11 | nouadhibou
# Processing Record 43 of Set 11 | paka
# Processing Record 44 of Set 11 | komsomolskiy
# Processing Record 45 of Set 11 | kloulklubed
# Processing Record 46 of Set 11 | takoradi
# Processing Record 47 of Set 11 | shieli
# Processing Record 48 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 49 of Set 11 | berlevag
# Processing Record 50 of Set 11 | yei
# Processing Record 1 of Set 12 | bandarbeyla
# Processing Record 2 of Set 12 | lesosibirsk
# Processing Record 3 of Set 12 | te anau
# Processing Record 4 of Set 12 | omaruru
# Processing Record 5 of Set 12 | sangar
# Processing Record 6 of Set 12 | cidreira
# Processing Record 7 of Set 12 | alta floresta
# Processing Record 8 of Set 12 | platanos
# Processing Record 9 of Set 12 | dongying
# Processing Record 10 of Set 12 | wanning
# Processing Record 11 of Set 12 | saint-joseph
# Processing Record 12 of Set 12 | abu dhabi
# Processing Record 13 of Set 12 | codrington
# Processing Record 14 of Set 12 | mpulungu
# Processing Record 15 of Set 12 | bonnyville
# Processing Record 16 of Set 12 | north branch
# Processing Record 17 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 12 | haines junction
# Processing Record 19 of Set 12 | carbonia
# Processing Record 20 of Set 12 | laguna
# Processing Record 21 of Set 12 | torbay
# Processing Record 22 of Set 12 | eureka
# Processing Record 23 of Set 12 | itoman
# Processing Record 24 of Set 12 | kirakira
# Processing Record 25 of Set 12 | roxana
# Processing Record 26 of Set 12 | alice springs
# Processing Record 27 of Set 12 | arrecife
# Processing Record 28 of Set 12 | boende
# Processing Record 29 of Set 12 | maningrida
# Processing Record 30 of Set 12 | port-gentil
# Processing Record 31 of Set 12 | jaworzno
# Processing Record 32 of Set 12 | lieksa
# Processing Record 33 of Set 12 | diffa
# Processing Record 34 of Set 12 | tura
# Processing Record 35 of Set 12 | bowen
# Processing Record 36 of Set 12 | harper
# Processing Record 37 of Set 12 | yulara
# Processing Record 38 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 12 | dargaville
# Processing Record 40 of Set 12 | mayo
# Processing Record 41 of Set 12 | mesyagutovo
# Processing Record 42 of Set 12 | ixtapa
# Processing Record 43 of Set 12 | goure
# Processing Record 44 of Set 12 | gualaquiza
# Processing Record 45 of Set 12 | kargasok
# Processing Record 46 of Set 12 | saint-francois
# Processing Record 47 of Set 12 | adre
# Processing Record 48 of Set 12 | kilindoni
# Processing Record 49 of Set 12 | tanout
# Processing Record 50 of Set 12 | nogales
# Processing Record 1 of Set 13 | nizhniy odes
# Processing Record 2 of Set 13 | valparaiso
# Processing Record 3 of Set 13 | jurm
# Processing Record 4 of Set 13 | iberia
# Processing Record 5 of Set 13 | saavedra
# Processing Record 6 of Set 13 | inta
# Processing Record 7 of Set 13 | zhaoyuan
# Processing Record 8 of Set 13 | baghdad
# Processing Record 9 of Set 13 | lokosovo
# Processing Record 10 of Set 13 | el fuerte
# Processing Record 11 of Set 13 | kaniama
# Processing Record 12 of Set 13 | pisco
# Processing Record 13 of Set 13 | kon tum
# Processing Record 14 of Set 13 | batagay-alyta
# Processing Record 15 of Set 13 | lusaka
# Processing Record 16 of Set 13 | kiunga
# Processing Record 17 of Set 13 | khipro
# Processing Record 18 of Set 13 | aldan
# Processing Record 19 of Set 13 | urulga
# City not found. Skipping...
# Processing Record 20 of Set 13 | katsuura
# Processing Record 21 of Set 13 | zhigansk
# Processing Record 22 of Set 13 | buckeye
# Processing Record 23 of Set 13 | gavle
# Processing Record 24 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 13 | saurimo
# Processing Record 26 of Set 13 | vostok
# Processing Record 27 of Set 13 | imphal
# Processing Record 28 of Set 13 | walvis bay
# Processing Record 29 of Set 13 | boa esperanca
# Processing Record 30 of Set 13 | lubumbashi
# Processing Record 31 of Set 13 | iaciara
# Processing Record 32 of Set 13 | tiarei
# Processing Record 33 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 13 | horsham
# Processing Record 35 of Set 13 | bilibino
# Processing Record 36 of Set 13 | santa luzia
# Processing Record 37 of Set 13 | daru
# Processing Record 38 of Set 13 | trat
# Processing Record 39 of Set 13 | vytegra
# Processing Record 40 of Set 13 | kodinar
# Processing Record 41 of Set 13 | santa fe
# Processing Record 42 of Set 13 | santa maria
# Processing Record 43 of Set 13 | kang
# Processing Record 44 of Set 13 | urucui
# Processing Record 45 of Set 13 | berkovica
# Processing Record 46 of Set 13 | palmer
# Processing Record 47 of Set 13 | seymchan
# Processing Record 48 of Set 13 | helong
# Processing Record 49 of Set 13 | ojinaga
# Processing Record 50 of Set 13 | nicoya
# Processing Record 1 of Set 14 | raga
# Processing Record 2 of Set 14 | kokstad
# Processing Record 3 of Set 14 | sorong
# Processing Record 4 of Set 14 | miraflores
# Processing Record 5 of Set 14 | dongli
# Processing Record 6 of Set 14 | luderitz
# Processing Record 7 of Set 14 | nemuro
# Processing Record 8 of Set 14 | concepcion del oro
# Processing Record 9 of Set 14 | sheridan
# Processing Record 10 of Set 14 | leshukonskoye
# Processing Record 11 of Set 14 | omboue
# Processing Record 12 of Set 14 | ternate
# Processing Record 13 of Set 14 | nelson bay
# Processing Record 14 of Set 14 | pangody
# Processing Record 15 of Set 14 | praia
# Processing Record 16 of Set 14 | pshekhskaya
# Processing Record 17 of Set 14 | kutum
# Processing Record 18 of Set 14 | sampit
# Processing Record 19 of Set 14 | tual
# Processing Record 20 of Set 14 | nuuk
# Processing Record 21 of Set 14 | winslow
# Processing Record 22 of Set 14 | bonavista
# Processing Record 23 of Set 14 | svetlyy
# Processing Record 24 of Set 14 | honningsvag
# Processing Record 25 of Set 14 | srikakulam
# Processing Record 26 of Set 14 | tahoua
# Processing Record 27 of Set 14 | feicheng
# Processing Record 28 of Set 14 | brufut
# Processing Record 29 of Set 14 | usinsk
# Processing Record 30 of Set 14 | muzhi
# Processing Record 31 of Set 14 | hovd
# Processing Record 32 of Set 14 | sohag
# Processing Record 33 of Set 14 | bomet
# Processing Record 34 of Set 14 | juneau
# Processing Record 35 of Set 14 | antalaha
# Processing Record 36 of Set 14 | barcelona
# Processing Record 37 of Set 14 | hokitika
# Processing Record 38 of Set 14 | noshiro
# Processing Record 39 of Set 14 | gazojak
# Processing Record 40 of Set 14 | eenhana
# Processing Record 41 of Set 14 | henderson
# Processing Record 42 of Set 14 | jiaozhou
# Processing Record 43 of Set 14 | tarazona
# Processing Record 44 of Set 14 | bitung
# Processing Record 45 of Set 14 | jiwani
# Processing Record 46 of Set 14 | hamilton
# Processing Record 47 of Set 14 | nevelsk
# Processing Record 48 of Set 14 | zyryanka
# Processing Record 49 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 14 | turinsk
# Processing Record 1 of Set 15 | benjamin aceval
# Processing Record 2 of Set 15 | capao da canoa
# Processing Record 3 of Set 15 | auki
# Processing Record 4 of Set 15 | qui nhon
# Processing Record 5 of Set 15 | turukhansk
# Processing Record 6 of Set 15 | hanna
# Processing Record 7 of Set 15 | arcoverde
# Processing Record 8 of Set 15 | limbang
# Processing Record 9 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 15 | hammerfest
# Processing Record 11 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 15 | padang
# Processing Record 13 of Set 15 | itambacuri
# Processing Record 14 of Set 15 | ikom
# Processing Record 15 of Set 15 | ubinskoye
# Processing Record 16 of Set 15 | hami
# Processing Record 17 of Set 15 | huilong
# Processing Record 18 of Set 15 | hualmay
# Processing Record 19 of Set 15 | ouadda
# Processing Record 20 of Set 15 | trinidad
# Processing Record 21 of Set 15 | pathein
# Processing Record 22 of Set 15 | axim
# Processing Record 23 of Set 15 | mazamari
# Processing Record 24 of Set 15 | chicama
# Processing Record 25 of Set 15 | chino valley
# Processing Record 26 of Set 15 | bathsheba
# Processing Record 27 of Set 15 | celestun
# Processing Record 28 of Set 15 | hobyo
# Processing Record 29 of Set 15 | kousseri
# Processing Record 30 of Set 15 | coromandel
# Processing Record 31 of Set 15 | aksarayskiy
# Processing Record 32 of Set 15 | mizan teferi
# Processing Record 33 of Set 15 | goderich
# Processing Record 34 of Set 15 | boguchany
# Processing Record 35 of Set 15 | moerai
# Processing Record 36 of Set 15 | totness
# Processing Record 37 of Set 15 | kozhva
# Processing Record 38 of Set 15 | birao
# Processing Record 39 of Set 15 | petropavlovka
# Processing Record 40 of Set 15 | horta
# Processing Record 41 of Set 15 | burns lake
# Processing Record 42 of Set 15 | inirida
# Processing Record 43 of Set 15 | collie
# Processing Record 44 of Set 15 | anaconda
# Processing Record 45 of Set 15 | vao
# Processing Record 46 of Set 15 | kudat
# Processing Record 47 of Set 15 | tabuleiro do norte
# Processing Record 48 of Set 15 | puno
# Processing Record 49 of Set 15 | grand-santi
# Processing Record 50 of Set 15 | arlit
# Processing Record 1 of Set 16 | atar
# Processing Record 2 of Set 16 | katobu
# Processing Record 3 of Set 16 | chapais
# Processing Record 4 of Set 16 | sol-iletsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Zaraza      VE   9.3503  -65.3245     75.33        77           4
# 1      Benguela      AO -12.5763   13.4055     73.94        73         100
# 2      Tasiilaq      GL  65.6145  -37.6368     24.96        69         100
# 3       Qaanaaq      GL  77.4840  -69.3632      1.17        70         100
# 4        Bethel      US  41.3712  -73.4140     31.50        84         100
# 5        Dryden      CA  49.7833  -92.7503     -3.71        71           0
# 6       Rikitea      PF -23.1203 -134.9692     79.05        68           4
# 7  Bogorodskoye      RU  56.5500   37.8833      0.41       100          99
# 8     Cape Town      ZA -33.9258   18.4232     65.88        67           0
# 9      Hermanus      ZA -34.4187   19.2345     63.81        70           1
#
#    Wind Speed Current Description                 Date
# 0        9.71           clear sky  2022-02-05 01:39:04
# 1        4.94     overcast clouds  2022-02-05 01:36:40
# 2       42.73     overcast clouds  2022-02-05 01:34:37
# 3        6.51     overcast clouds  2022-02-05 01:34:47
# 4        8.05     overcast clouds  2022-02-05 01:39:05
# 5        5.75           clear sky  2022-02-05 01:39:05
# 6        7.18           clear sky  2022-02-05 01:39:06
# 7        1.66     overcast clouds  2022-02-05 01:39:06
# 8        5.01           clear sky  2022-02-05 01:37:51
# 9       18.03           clear sky  2022-02-05 01:39:07

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
